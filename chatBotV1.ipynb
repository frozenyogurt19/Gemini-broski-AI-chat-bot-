# %% [markdown]
# # Gemini Chat Bot (on phone)

# %% [markdown]
# v1: basic API call and creating  Memory

# %%
with open("apikey.txt", "r") as f:
    my_api_key = f.read().strip()
# Out:
# 'AIzaSyDO05Pv3m1ij6TVti_iiGGOPj8qWZLAk9Q'

# %%
"""
from google import genai

client = genai.Client(api_key=my_api_key)

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="print pizza emoji",
)

print(response.text)
"""
# Out:
# '\nfrom google import genai\n\nclient = genai.Client(api_key=my_api_key)\n\nresponse = client.models.generate_content(\n    model="gemini-3-flash-preview",\n    contents="print pizza emoji",\n)\n\nprint(response.text)\n'

# %%
"""
 Understand how message history works (user/assistant turn structure)
 Store the conversation as an array that grows with each exchange
 Pass the full history on every API call so the AI has context
 Decide when/how to trim history (token limits are real)

"""
# Out:
# '\n Understand how message history works (user/assistant turn structure)\n Store the conversation as an array that grows with each exchange\n Pass the full history on every API call so the AI has context\n Decide when/how to trim history (token limits are real)\n\n'

# %%
# creating list: current_chat = []

# client: "hello !" (current_chat = ["hello !"])
# gemini : "hi" (via API) (current_chat = ["hello !",  "hi"  ])
# me: "what did i just say ? (current_chat = ["hello !",  "hi" , "what did i just say ?  ])
# gemini: "you said hello"  (current_chat = ["hello !",  "hi" , "what did i just say ?,  "you said hello" ...  ])

# %%
from google import genai

client = genai.Client(api_key=my_api_key)

response = client.models.generate_content(
    model="gemini-3-flash-preview" ,
    contents="start the convo, like good morning or welcome"
)

chat_history = []
first_chat = False

# gemini start convo with (response.text)
print(response.text)
# adding to chat history ( google genai accepts "text" key inside "parts")
chat_history.append( {"role": "model", "parts": [{ "text": response.text}] })

my_reply ="" # i say nothing at first 

#  infinite contents:-
while  "bye" not in my_reply:

    if not first_chat:
        first_chat = True
    else:
        # gemini continues convo, now with a history 
        response = client.models.generate_content(
        model="gemini-3-flash-preview" ,
        contents= chat_history
    )
        # adding to chat history 
        chat_history.append( {"role": "model", "parts": [{ "text": response.text}] })

        print("gemini: "+  response.text)


    # i reply to response.text 
    my_reply = input(response.text) 
    print("me: "+ str(my_reply))
    # adding to chat history 
    chat_history.append( {"role": "user", "parts": [{ "text": str(my_reply)}] })
# Out:
# Good morning! It’s a pleasure to meet you. Welcome!
#
# How can I help you get started today?
# me: hi what day is tit
# gemini: Today is **Tuesday, May 21, 2024**.
#
# How can I help you with your plans for today?
# me: ok bye

# %% [markdown]
# tod0 ; remove live server and cors so change smtng in flask server
